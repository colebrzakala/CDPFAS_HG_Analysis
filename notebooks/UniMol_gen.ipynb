# %% [markdown]
# # UniMol2 Feature Generation
#
# This notebook shows how the UniMol2 representations were created for the training and test datasets.

# %%
import numpy as np
from unimol_tools import UniMolRepr
# Out:
# 2025-08-13 11:38:25 | unimol_tools\weights\weighthub.py | 17 | INFO | Uni-Mol Tools | Weights will be downloaded to default directory: c:\Users\cbrzakala\AppData\Local\anaconda3\Lib\site-packages\unimol_tools\weights

# %%
clf = UniMolRepr(
    data_type="molecule",
    remove_hs=False,
    model_name="unimolv2",  # avaliable: unimolv1, unimolv2
    model_size="84m",  # work when model_name is unimolv2. avaliable: 84m, 164m, 310m, 570m, 1.1B.
)
# Out:
# 2025-08-13 11:38:29 | unimol_tools\models\unimolv2.py | 144 | INFO | Uni-Mol Tools | Loading pretrained weights from c:\Users\cbrzakala\AppData\Local\anaconda3\Lib\site-packages\unimol_tools\weights\modelzoo/84M/checkpoint.pt

# %%
import pandas as pd

host_df = pd.read_csv("host_smiles.csv")
guest_df = pd.read_csv("guest_smiles.csv")

host_smiles = host_df["smiles"].tolist()
guest_smiles = guest_df["smiles"].tolist()

# %%
# Define a function to process data in chunks and return a DataFrame
def process_in_chunks(smiles_list, chunk_size=100):
    repr_list = []
    for i in range(0, len(smiles_list), chunk_size):
        chunk = smiles_list[i : i + chunk_size]
        chunk_repr = clf.get_repr(chunk, return_atomic_reprs=False)
        repr_list.extend(chunk_repr["cls_repr"])
    # Convert the list of representations to a DataFrame
    repr_df = pd.DataFrame(repr_list)
    return repr_df

# %%
# Process host_smiles in chunks
host_repr = process_in_chunks(host_smiles)

# Convert to DataFrame and save to CSV
host_repr_df = pd.DataFrame(host_repr)
host_repr_df.to_csv("host_representations.csv", index=False)

# %%
# Process guest_smiles in chunks
guest_repr = process_in_chunks(guest_smiles)

# Convert to DataFrame and save to CSV
guest_repr_df = pd.DataFrame(guest_repr)
guest_repr_df.to_csv("guest_representations.csv", index=False)
# Out:
# 2025-02-05 11:13:29 | unimol_tools\data\conformer.py | 333 | INFO | Uni-Mol Tools | Start generating conformers...
# 100%|██████████| 100/100 [00:02<00:00, 43.57it/s]
# 2025-02-05 11:13:31 | unimol_tools\data\conformer.py | 342 | INFO | Uni-Mol Tools | Succeeded in generating conformers for 100.00% of molecules.
# 2025-02-05 11:13:31 | unimol_tools\data\conformer.py | 349 | INFO | Uni-Mol Tools | Succeeded in generating 3d conformers for 100.00% of molecules.
# 100%|██████████| 4/4 [00:12<00:00,  3.14s/it]
# 2025-02-05 11:13:44 | unimol_tools\data\conformer.py | 333 | INFO | Uni-Mol Tools | Start generating conformers...
# 100%|██████████| 100/100 [00:01<00:00, 68.17it/s]
# 2025-02-05 11:13:45 | unimol_tools\data\conformer.py | 342 | INFO | Uni-Mol Tools | Succeeded in generating conformers for 100.00% of molecules.
# 2025-02-05 11:13:45 | unimol_tools\data\conformer.py | 349 | INFO | Uni-Mol Tools | Succeeded in generating 3d conformers for 100.00% of molecules.
# 100%|██████████| 4/4 [00:08<00:00,  2.24s/it]
# 2025-02-05 11:13:54 | unimol_tools\data\conformer.py | 333 | INFO | Uni-Mol Tools | Start generating conformers...
# 100%|██████████| 100/100 [00:01<00:00, 53.01it/s]
# 2025-02-05 11:13:56 | unimol_tools\data\conformer.py | 342 | INFO | Uni-Mol Tools | Succeeded in generating conformers for 100.00% of molecules.
# 2025-02-05 11:13:56 | unimol_tools\data\conformer.py | 349 | INFO | Uni-Mol Tools | Succeeded in generating 3d conformers for 100.00% of molecules.
# 100%|██████████| 4/4 [00:13<00:00,  3.25s/it]
# 2025-02-05 11:14:09 | unimol_tools\data\conformer.py | 333 | INFO | Uni-Mol Tools | Start generating conformers...
# 100%|██████████| 100/100 [00:01<00:00, 72.33it/s]
# 2025-02-05 11:14:11 | unimol_tools\data\conformer.py | 342 | INFO | Uni-Mol Tools | Succeeded in generating conformers for 100.00% of molecules.
# 2025-02-05 11:14:11 | unimol_tools\data\conformer.py | 349 | INFO | Uni-Mol Tools | Succeeded in generating 3d conformers for 100.00% of molecules.
# 100%|██████████| 4/4 [00:11<00:00,  2.85s/it]
# 2025-02-05 11:14:22 | unimol_tools\data\conformer.py | 333 | INFO | Uni-Mol Tools | Start generating conformers...
# 100%|██████████| 100/100 [00:00<00:00, 106.91it/s]
# 2025-02-05 11:14:23 | unimol_tools\data\conformer.py | 342 | INFO | Uni-Mol Tools | Succeeded in generating conformers for 100.00% of molecules.
# 2025-02-05 11:14:23 | unimol_tools\data\conformer.py | 349 | INFO | Uni-Mol Tools | Succeeded in generating 3d conformers for 100.00% of molecules.
# 100%|██████████| 4/4 [00:08<00:00,  2.09s/it]
# 2025-02-05 11:14:32 | unimol_tools\data\conformer.py | 333 | INFO | Uni-Mol Tools | Start generating conformers...
# 100%|██████████| 100/100 [00:01<00:00, 63.24it/s]
# 2025-02-05 11:14:33 | unimol_tools\data\conformer.py | 342 | INFO | Uni-Mol Tools | Succeeded in generating conformers for 100.00% of molecules.
# 2025-02-05 11:14:33 | unimol_tools\data\conformer.py | 349 | INFO | Uni-Mol Tools | Succeeded in generating 3d conformers for 99.00% of molecules.
# 2025-02-05 11:14:33 | unimol_tools\data\conformer.py | 352 | INFO | Uni-Mol Tools | Failed 3d conformers indices: [27]
# 100%|██████████| 4/4 [00:20<00:00,  5.14s/it]
# 2025-02-05 11:14:54 | unimol_tools\data\conformer.py | 333 | INFO | Uni-Mol Tools | Start generating conformers...
# 100%|██████████| 100/100 [00:02<00:00, 36.02it/s]
# 2025-02-05 11:14:57 | unimol_tools\data\conformer.py | 342 | INFO | Uni-Mol Tools | Succeeded in generating conformers for 100.00% of molecules.
# 2025-02-05 11:14:57 | unimol_tools\data\conformer.py | 349 | INFO | Uni-Mol Tools | Succeeded in generating 3d conformers for 100.00% of molecules.
# 100%|██████████| 4/4 [00:42<00:00, 10.61s/it]
# 2025-02-05 11:15:39 | unimol_tools\data\conformer.py | 333 | INFO | Uni-Mol Tools | Start generating conformers...
# 100%|██████████| 100/100 [00:01<00:00, 61.63it/s]
# 2025-02-05 11:15:41 | unimol_tools\data\conformer.py | 342 | INFO | Uni-Mol Tools | Succeeded in generating conformers for 100.00% of molecules.
# 2025-02-05 11:15:41 | unimol_tools\data\conformer.py | 349 | INFO | Uni-Mol Tools | Succeeded in generating 3d conformers for 100.00% of molecules.
# 100%|██████████| 4/4 [00:27<00:00,  6.75s/it]
# 2025-02-05 11:16:08 | unimol_tools\data\conformer.py | 333 | INFO | Uni-Mol Tools | Start generating conformers...
# 100%|██████████| 100/100 [00:01<00:00, 78.65it/s]
# 2025-02-05 11:16:09 | unimol_tools\data\conformer.py | 342 | INFO | Uni-Mol Tools | Succeeded in generating conformers for 100.00% of molecules.
# 2025-02-05 11:16:09 | unimol_tools\data\conformer.py | 349 | INFO | Uni-Mol Tools | Succeeded in generating 3d conformers for 100.00% of molecules.
# 100%|██████████| 4/4 [00:14<00:00,  3.50s/it]
# 2025-02-05 11:16:23 | unimol_tools\data\conformer.py | 333 | INFO | Uni-Mol Tools | Start generating conformers...
# 100%|██████████| 100/100 [00:04<00:00, 21.06it/s]
# 2025-02-05 11:16:28 | unimol_tools\data\conformer.py | 342 | INFO | Uni-Mol Tools | Succeeded in generating conformers for 100.00% of molecules.
# 2025-02-05 11:16:28 | unimol_tools\data\conformer.py | 349 | INFO | Uni-Mol Tools | Succeeded in generating 3d conformers for 100.00% of molecules.
# 100%|██████████| 4/4 [00:49<00:00, 12.49s/it]
# 2025-02-05 11:17:18 | unimol_tools\data\conformer.py | 333 | INFO | Uni-Mol Tools | Start generating conformers...
# 100%|██████████| 100/100 [00:04<00:00, 21.81it/s]
# 2025-02-05 11:17:22 | unimol_tools\data\conformer.py | 342 | INFO | Uni-Mol Tools | Succeeded in generating conformers for 100.00% of molecules.
# 2025-02-05 11:17:22 | unimol_tools\data\conformer.py | 349 | INFO | Uni-Mol Tools | Succeeded in generating 3d conformers for 99.00% of molecules.
# 2025-02-05 11:17:22 | unimol_tools\data\conformer.py | 352 | INFO | Uni-Mol Tools | Failed 3d conformers indices: [50]
# 100%|██████████| 4/4 [01:10<00:00, 17.72s/it]
# 2025-02-05 11:18:34 | unimol_tools\data\conformer.py | 333 | INFO | Uni-Mol Tools | Start generating conformers...
# 100%|██████████| 100/100 [00:07<00:00, 13.64it/s]
# 2025-02-05 11:18:41 | unimol_tools\data\conformer.py | 342 | INFO | Uni-Mol Tools | Succeeded in generating conformers for 100.00% of molecules.
# 2025-02-05 11:18:41 | unimol_tools\data\conformer.py | 349 | INFO | Uni-Mol Tools | Succeeded in generating 3d conformers for 100.00% of molecules.
# 100%|██████████| 4/4 [00:47<00:00, 12.00s/it]
# 2025-02-05 11:19:29 | unimol_tools\data\conformer.py | 333 | INFO | Uni-Mol Tools | Start generating conformers...
# 100%|██████████| 100/100 [00:04<00:00, 21.47it/s]
# 2025-02-05 11:19:34 | unimol_tools\data\conformer.py | 342 | INFO | Uni-Mol Tools | Succeeded in generating conformers for 100.00% of molecules.
# 2025-02-05 11:19:34 | unimol_tools\data\conformer.py | 349 | INFO | Uni-Mol Tools | Succeeded in generating 3d conformers for 100.00% of molecules.
# 100%|██████████| 4/4 [00:36<00:00,  9.23s/it]
# 2025-02-05 11:20:11 | unimol_tools\data\conformer.py | 333 | INFO | Uni-Mol Tools | Start generating conformers...
# 100%|██████████| 100/100 [00:04<00:00, 24.31it/s]
# 2025-02-05 11:20:15 | unimol_tools\data\conformer.py | 342 | INFO | Uni-Mol Tools | Succeeded in generating conformers for 100.00% of molecules.
# 2025-02-05 11:20:15 | unimol_tools\data\conformer.py | 349 | INFO | Uni-Mol Tools | Succeeded in generating 3d conformers for 100.00% of molecules.
# 100%|██████████| 4/4 [00:37<00:00,  9.47s/it]
# 2025-02-05 11:20:53 | unimol_tools\data\conformer.py | 333 | INFO | Uni-Mol Tools | Start generating conformers...
# 100%|██████████| 100/100 [00:06<00:00, 16.39it/s]
# 2025-02-05 11:20:59 | unimol_tools\data\conformer.py | 342 | INFO | Uni-Mol Tools | Succeeded in generating conformers for 100.00% of molecules.
# 2025-02-05 11:20:59 | unimol_tools\data\conformer.py | 349 | INFO | Uni-Mol Tools | Succeeded in generating 3d conformers for 100.00% of molecules.
# 100%|██████████| 4/4 [00:30<00:00,  7.52s/it]
# 2025-02-05 11:21:29 | unimol_tools\data\conformer.py | 333 | INFO | Uni-Mol Tools | Start generating conformers...
# 100%|██████████| 100/100 [00:06<00:00, 15.27it/s]
# 2025-02-05 11:21:36 | unimol_tools\data\conformer.py | 342 | INFO | Uni-Mol Tools | Succeeded in generating conformers for 100.00% of molecules.
# 2025-02-05 11:21:36 | unimol_tools\data\conformer.py | 349 | INFO | Uni-Mol Tools | Succeeded in generating 3d conformers for 99.00% of molecules.
# 2025-02-05 11:21:36 | unimol_tools\data\conformer.py | 352 | INFO | Uni-Mol Tools | Failed 3d conformers indices: [71]
# 100%|██████████| 4/4 [00:48<00:00, 12.25s/it]
# 2025-02-05 11:22:25 | unimol_tools\data\conformer.py | 333 | INFO | Uni-Mol Tools | Start generating conformers...
# 100%|██████████| 100/100 [00:04<00:00, 20.23it/s]
# 2025-02-05 11:22:30 | unimol_tools\data\conformer.py | 342 | INFO | Uni-Mol Tools | Succeeded in generating conformers for 100.00% of molecules.
# 2025-02-05 11:22:30 | unimol_tools\data\conformer.py | 349 | INFO | Uni-Mol Tools | Succeeded in generating 3d conformers for 100.00% of molecules.
# 100%|██████████| 4/4 [00:46<00:00, 11.56s/it]
# 2025-02-05 11:23:16 | unimol_tools\data\conformer.py | 333 | INFO | Uni-Mol Tools | Start generating conformers...
# 100%|██████████| 100/100 [00:03<00:00, 25.94it/s]
# 2025-02-05 11:23:20 | unimol_tools\data\conformer.py | 342 | INFO | Uni-Mol Tools | Succeeded in generating conformers for 100.00% of molecules.
# 2025-02-05 11:23:20 | unimol_tools\data\conformer.py | 349 | INFO | Uni-Mol Tools | Succeeded in generating 3d conformers for 100.00% of molecules.
# 100%|██████████| 4/4 [01:07<00:00, 16.94s/it]
# 2025-02-05 11:24:28 | unimol_tools\data\conformer.py | 333 | INFO | Uni-Mol Tools | Start generating conformers...
# 100%|██████████| 100/100 [00:02<00:00, 34.07it/s]
# 2025-02-05 11:24:31 | unimol_tools\data\conformer.py | 342 | INFO | Uni-Mol Tools | Succeeded in generating conformers for 100.00% of molecules.
# 2025-02-05 11:24:31 | unimol_tools\data\conformer.py | 349 | INFO | Uni-Mol Tools | Succeeded in generating 3d conformers for 100.00% of molecules.
# 100%|██████████| 4/4 [00:42<00:00, 10.70s/it]
# 2025-02-05 11:25:13 | unimol_tools\data\conformer.py | 333 | INFO | Uni-Mol Tools | Start generating conformers...
# 100%|██████████| 100/100 [00:05<00:00, 19.60it/s]
# 2025-02-05 11:25:19 | unimol_tools\data\conformer.py | 342 | INFO | Uni-Mol Tools | Succeeded in generating conformers for 100.00% of molecules.
# 2025-02-05 11:25:19 | unimol_tools\data\conformer.py | 349 | INFO | Uni-Mol Tools | Succeeded in generating 3d conformers for 99.00% of molecules.
# 2025-02-05 11:25:19 | unimol_tools\data\conformer.py | 352 | INFO | Uni-Mol Tools | Failed 3d conformers indices: [80]
# 100%|██████████| 4/4 [00:37<00:00,  9.42s/it]
# 2025-02-05 11:25:56 | unimol_tools\data\conformer.py | 333 | INFO | Uni-Mol Tools | Start generating conformers...
# 100%|██████████| 100/100 [00:04<00:00, 24.62it/s]
# 2025-02-05 11:26:00 | unimol_tools\data\conformer.py | 342 | INFO | Uni-Mol Tools | Succeeded in generating conformers for 100.00% of molecules.
# 2025-02-05 11:26:00 | unimol_tools\data\conformer.py | 349 | INFO | Uni-Mol Tools | Succeeded in generating 3d conformers for 100.00% of molecules.
# 100%|██████████| 4/4 [00:47<00:00, 11.99s/it]
# 2025-02-05 11:26:48 | unimol_tools\data\conformer.py | 333 | INFO | Uni-Mol Tools | Start generating conformers...
# 100%|██████████| 100/100 [00:03<00:00, 25.00it/s]
# 2025-02-05 11:26:52 | unimol_tools\data\conformer.py | 342 | INFO | Uni-Mol Tools | Succeeded in generating conformers for 100.00% of molecules.
# 2025-02-05 11:26:52 | unimol_tools\data\conformer.py | 349 | INFO | Uni-Mol Tools | Succeeded in generating 3d conformers for 100.00% of molecules.
# 100%|██████████| 4/4 [00:39<00:00,  9.80s/it]
# 2025-02-05 11:27:32 | unimol_tools\data\conformer.py | 333 | INFO | Uni-Mol Tools | Start generating conformers...
# 100%|██████████| 100/100 [00:07<00:00, 14.01it/s]
# 2025-02-05 11:27:39 | unimol_tools\data\conformer.py | 342 | INFO | Uni-Mol Tools | Succeeded in generating conformers for 100.00% of molecules.
# 2025-02-05 11:27:39 | unimol_tools\data\conformer.py | 349 | INFO | Uni-Mol Tools | Succeeded in generating 3d conformers for 100.00% of molecules.
# 100%|██████████| 4/4 [00:50<00:00, 12.51s/it]
# 2025-02-05 11:28:29 | unimol_tools\data\conformer.py | 333 | INFO | Uni-Mol Tools | Start generating conformers...
# 100%|██████████| 100/100 [00:02<00:00, 45.53it/s]
# 2025-02-05 11:28:31 | unimol_tools\data\conformer.py | 342 | INFO | Uni-Mol Tools | Succeeded in generating conformers for 100.00% of molecules.
# 2025-02-05 11:28:31 | unimol_tools\data\conformer.py | 349 | INFO | Uni-Mol Tools | Succeeded in generating 3d conformers for 100.00% of molecules.
# 100%|██████████| 4/4 [00:37<00:00,  9.32s/it]
# 2025-02-05 11:29:08 | unimol_tools\data\conformer.py | 333 | INFO | Uni-Mol Tools | Start generating conformers...
# 100%|██████████| 100/100 [00:03<00:00, 26.09it/s]
# 2025-02-05 11:29:12 | unimol_tools\data\conformer.py | 342 | INFO | Uni-Mol Tools | Succeeded in generating conformers for 100.00% of molecules.
# 2025-02-05 11:29:12 | unimol_tools\data\conformer.py | 349 | INFO | Uni-Mol Tools | Succeeded in generating 3d conformers for 100.00% of molecules.
# 100%|██████████| 4/4 [00:45<00:00, 11.49s/it]
# 2025-02-05 11:29:58 | unimol_tools\data\conformer.py | 333 | INFO | Uni-Mol Tools | Start generating conformers...
# 100%|██████████| 100/100 [00:03<00:00, 32.28it/s]
# 2025-02-05 11:30:01 | unimol_tools\data\conformer.py | 342 | INFO | Uni-Mol Tools | Succeeded in generating conformers for 100.00% of molecules.
# 2025-02-05 11:30:01 | unimol_tools\data\conformer.py | 349 | INFO | Uni-Mol Tools | Succeeded in generating 3d conformers for 100.00% of molecules.
# 100%|██████████| 4/4 [00:37<00:00,  9.26s/it]
# 2025-02-05 11:30:39 | unimol_tools\data\conformer.py | 333 | INFO | Uni-Mol Tools | Start generating conformers...
# 100%|██████████| 100/100 [00:03<00:00, 31.64it/s]
# 2025-02-05 11:30:42 | unimol_tools\data\conformer.py | 342 | INFO | Uni-Mol Tools | Succeeded in generating conformers for 100.00% of molecules.
# 2025-02-05 11:30:42 | unimol_tools\data\conformer.py | 349 | INFO | Uni-Mol Tools | Succeeded in generating 3d conformers for 100.00% of molecules.
# 100%|██████████| 4/4 [00:28<00:00,  7.07s/it]
# 2025-02-05 11:31:10 | unimol_tools\data\conformer.py | 333 | INFO | Uni-Mol Tools | Start generating conformers...
# 100%|██████████| 100/100 [00:07<00:00, 12.62it/s]
# 2025-02-05 11:31:18 | unimol_tools\data\conformer.py | 342 | INFO | Uni-Mol Tools | Succeeded in generating conformers for 100.00% of molecules.
# 2025-02-05 11:31:18 | unimol_tools\data\conformer.py | 349 | INFO | Uni-Mol Tools | Succeeded in generating 3d conformers for 100.00% of molecules.
# 100%|██████████| 4/4 [00:46<00:00, 11.72s/it]
# 2025-02-05 11:32:05 | unimol_tools\data\conformer.py | 333 | INFO | Uni-Mol Tools | Start generating conformers...
# 100%|██████████| 100/100 [00:01<00:00, 76.81it/s]
# 2025-02-05 11:32:06 | unimol_tools\data\conformer.py | 342 | INFO | Uni-Mol Tools | Succeeded in generating conformers for 100.00% of molecules.
# 2025-02-05 11:32:06 | unimol_tools\data\conformer.py | 349 | INFO | Uni-Mol Tools | Succeeded in generating 3d conformers for 100.00% of molecules.
# 100%|██████████| 4/4 [00:20<00:00,  5.07s/it]
# 2025-02-05 11:32:27 | unimol_tools\data\conformer.py | 333 | INFO | Uni-Mol Tools | Start generating conformers...
# 100%|██████████| 100/100 [00:02<00:00, 35.63it/s]
# 2025-02-05 11:32:29 | unimol_tools\data\conformer.py | 342 | INFO | Uni-Mol Tools | Succeeded in generating conformers for 100.00% of molecules.
# 2025-02-05 11:32:29 | unimol_tools\data\conformer.py | 349 | INFO | Uni-Mol Tools | Succeeded in generating 3d conformers for 100.00% of molecules.
# 100%|██████████| 4/4 [00:58<00:00, 14.71s/it]
# 2025-02-05 11:33:28 | unimol_tools\data\conformer.py | 333 | INFO | Uni-Mol Tools | Start generating conformers...
# 100%|██████████| 100/100 [00:11<00:00,  8.52it/s]
# 2025-02-05 11:33:40 | unimol_tools\data\conformer.py | 342 | INFO | Uni-Mol Tools | Succeeded in generating conformers for 100.00% of molecules.
# 2025-02-05 11:33:40 | unimol_tools\data\conformer.py | 349 | INFO | Uni-Mol Tools | Succeeded in generating 3d conformers for 100.00% of molecules.
# 100%|██████████| 4/4 [01:18<00:00, 19.72s/it]
# 2025-02-05 11:34:59 | unimol_tools\data\conformer.py | 333 | INFO | Uni-Mol Tools | Start generating conformers...
# 100%|██████████| 100/100 [00:04<00:00, 23.19it/s]
# 2025-02-05 11:35:03 | unimol_tools\data\conformer.py | 342 | INFO | Uni-Mol Tools | Succeeded in generating conformers for 100.00% of molecules.
# 2025-02-05 11:35:03 | unimol_tools\data\conformer.py | 349 | INFO | Uni-Mol Tools | Succeeded in generating 3d conformers for 100.00% of molecules.
# 100%|██████████| 4/4 [00:56<00:00, 14.15s/it]
# 2025-02-05 11:36:00 | unimol_tools\data\conformer.py | 333 | INFO | Uni-Mol Tools | Start generating conformers...
# 100%|██████████| 100/100 [00:03<00:00, 27.99it/s]
# 2025-02-05 11:36:04 | unimol_tools\data\conformer.py | 342 | INFO | Uni-Mol Tools | Succeeded in generating conformers for 100.00% of molecules.
# 2025-02-05 11:36:04 | unimol_tools\data\conformer.py | 349 | INFO | Uni-Mol Tools | Succeeded in generating 3d conformers for 100.00% of molecules.
# 100%|██████████| 4/4 [00:54<00:00, 13.54s/it]
# 2025-02-05 11:36:58 | unimol_tools\data\conformer.py | 333 | INFO | Uni-Mol Tools | Start generating conformers...
# 100%|██████████| 100/100 [00:04<00:00, 20.62it/s]
# 2025-02-05 11:37:03 | unimol_tools\data\conformer.py | 342 | INFO | Uni-Mol Tools | Succeeded in generating conformers for 100.00% of molecules.
# 2025-02-05 11:37:03 | unimol_tools\data\conformer.py | 349 | INFO | Uni-Mol Tools | Succeeded in generating 3d conformers for 100.00% of molecules.
# 100%|██████████| 4/4 [00:48<00:00, 12.16s/it]
# 2025-02-05 11:37:51 | unimol_tools\data\conformer.py | 333 | INFO | Uni-Mol Tools | Start generating conformers...
# 100%|██████████| 59/59 [00:01<00:00, 49.58it/s]
# 2025-02-05 11:37:53 | unimol_tools\data\conformer.py | 342 | INFO | Uni-Mol Tools | Succeeded in generating conformers for 100.00% of molecules.
# 2025-02-05 11:37:53 | unimol_tools\data\conformer.py | 349 | INFO | Uni-Mol Tools | Succeeded in generating 3d conformers for 100.00% of molecules.
# 100%|██████████| 2/2 [00:18<00:00,  9.50s/it]

# %%
# Import host and guest representations from CSV files
host_repr_df = pd.read_csv("host_representations.csv")
guest_repr_df = pd.read_csv("guest_representations.csv")

# Print the shapes to verify the data
print("Host representations shape:", host_repr_df.shape)
print("Guest representations shape:", guest_repr_df.shape)
# Out:
# Host representations shape: (3459, 768)
# Guest representations shape: (3459, 768)

# %%
# Get molecular representations (cls_repr) for both host and guest
host_mol_repr = np.stack(host_repr_df.values)
guest_mol_repr = np.stack(guest_repr_df.values)

print("Host molecular representations shape:", host_mol_repr.shape)
print("Guest molecular representations shape:", guest_mol_repr.shape)

# Concatenate along feature axis (axis 1)
combined_repr = np.concatenate([host_mol_repr, guest_mol_repr], axis=1)

print("\nCombined representations shape:", combined_repr.shape)
# Out:
# Host molecular representations shape: (3459, 768)
# Guest molecular representations shape: (3459, 768)
#
# Combined representations shape: (3459, 1536)

# %%
# Convert the combined representation to a DataFrame
combined_repr_df = pd.DataFrame(combined_repr)

# Save the DataFrame to a CSV file
combined_repr_df.to_csv("unimol_rep.csv", index=False)

# %%
import pandas as pd
import numpy as np


# Function to process a file with Host_SMILES and Guest_SMILES columns and save concatenated unimol representations
def process_host_guest_file(input_file: str, output_file: str) -> None:
    """
    Processes a CSV file containing Host_SMILES and Guest_SMILES columns,
    generates unimol representations for each, concatenates them, and saves to a CSV file.

    Args:
        input_file (str): Path to the input CSV file.
        output_file (str): Path to the output CSV file.
    """
    # Type validation
    if not isinstance(input_file, str) or not isinstance(output_file, str):
        raise TypeError("Both input_file and output_file must be strings.")

    # Read the input file
    df = pd.read_csv(input_file)
    if "Host_SMILES" not in df.columns or "Guest_SMILES" not in df.columns:
        raise ValueError(
            "Input file must contain 'Host_SMILES' and 'Guest_SMILES' columns."
        )

    # Extract SMILES lists
    host_smiles_list = df["Host_SMILES"].tolist()
    guest_smiles_list = df["Guest_SMILES"].tolist()

    # Generate unimol representations for hosts and guests
    host_repr_df = process_in_chunks(host_smiles_list)
    guest_repr_df = process_in_chunks(guest_smiles_list)

    # Convert to numpy arrays for concatenation
    host_repr_np = np.stack(host_repr_df.values)
    guest_repr_np = np.stack(guest_repr_df.values)

    # Concatenate along feature axis (axis 1)
    combined_repr = np.concatenate([host_repr_np, guest_repr_np], axis=1)

    # Save to CSV
    combined_repr_df = pd.DataFrame(combined_repr)
    combined_repr_df.to_csv(output_file, index=False)


process_host_guest_file("cd_val_canonical.csv", "cd_val_unimol.csv")
process_host_guest_file("pfas_val_canonical.csv", "pfas_val_unimol.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 42
#      39     combined_repr_df = pd.DataFrame(combined_repr)
#      40     combined_repr_df.to_csv(output_file, index=False)
# ---> 42 process_host_guest_file("cd_val_canonical.csv", "cd_val_unimol.csv")
#      43 process_host_guest_file("pfas_val_canonical.csv", "pfas_val_unimol.csv")
#      44 process_host_guest_file("base_cdpfas_val_canonical.csv", "base_cdpfas_val_unimol.csv")
#
# Cell In[1], line 28, in process_host_guest_file(input_file, output_file)
#      25 guest_smiles_list = df["Guest_SMILES"].tolist()
#      27 # Generate unimol representations for hosts and guests
# ---> 28 host_repr_df = process_in_chunks(host_smiles_list)
#      29 guest_repr_df = process_in_chunks(guest_smiles_list)
#      31 # Convert to numpy arrays for concatenation
#
# NameError: name 'process_in_chunks' is not defined

# %%
process_host_guest_file("base_cdpfas_val_canonical.csv", "base_cdpfas_val_unimol.csv")
# Out:
# 2025-08-13 11:38:43 | unimol_tools\data\conformer.py | 333 | INFO | Uni-Mol Tools | Start generating conformers...
# 100%|██████████| 11/11 [00:14<00:00,  1.31s/it]
# 2025-08-13 11:38:57 | unimol_tools\data\conformer.py | 342 | INFO | Uni-Mol Tools | Succeeded in generating conformers for 100.00% of molecules.
# 2025-08-13 11:38:57 | unimol_tools\data\conformer.py | 349 | INFO | Uni-Mol Tools | Succeeded in generating 3d conformers for 100.00% of molecules.
# 100%|██████████| 1/1 [00:41<00:00, 41.64s/it]
# 2025-08-13 11:39:39 | unimol_tools\data\conformer.py | 333 | INFO | Uni-Mol Tools | Start generating conformers...
# 100%|██████████| 11/11 [00:00<00:00, 47.61it/s]
# 2025-08-13 11:39:39 | unimol_tools\data\conformer.py | 342 | INFO | Uni-Mol Tools | Succeeded in generating conformers for 100.00% of molecules.
# 2025-08-13 11:39:39 | unimol_tools\data\conformer.py | 349 | INFO | Uni-Mol Tools | Succeeded in generating 3d conformers for 100.00% of molecules.
# 100%|██████████| 1/1 [00:06<00:00,  6.77s/it]
